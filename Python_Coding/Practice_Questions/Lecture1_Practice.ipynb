# %% [markdown]
# # Practice Question: Chapters 1.1-1.3, 2.1-2.3 Python Basics and Markdown

# %% [markdown]
# ## Topics Covered
# - Why python?
# - Markdown
# - Language semantics
# - functions
# - Indentation
# - Objects
# - Mutable and immutable
# - Comments
# - Variables
# - binding
# - type and casting
# - operations
# - Scalar types
# - Numeric types
# - Strings
# - String ops
# - print
# - control flow
# - if, elif, else
# - loops
# - for
# - range
# - while
